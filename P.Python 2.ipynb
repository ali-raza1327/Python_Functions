# %%
def my_function(*kids):
  print('The youngest child is: '+kids[1])

my_function('Ali','kami','nomi')


def my_function(child1, child2, child3):
  print('\nThe youngest child is: '+child3)

my_function(child1='Ali', child2='kami', child3='nomi')
# Out:
# The youngest child is: kami
#
# The youngest child is: nomi

# %%
def my_myfuntion(**kid):
  print('his last name is '+kid['lname'].upper())

my_myfuntion(fname='Ali',lname='raza')
# Out:
# his last name is RAZA

# %%
def my_function(country = 'pakistan'):
  print('I am from: ' +country.upper())

my_function('india')
my_function('sweden')
my_function()
my_function('brazil')
# Out:
# I am from: INDIA
# I am from: SWEDEN
# I am from: PAKISTAN
# I am from: BRAZIL

# %%
def my_function(*,x):
  print(x)

my_function(x=3)
# Out:
# 3

# %%
def my_function(n):
  return lambda a:a*n
mydoubler=my_function(2)
mytripler=my_function(3)
print(mydoubler(11))
print(mytripler(11))
# Out:
# 22
# 33

# %%
# arrays in python

cars=["volvo","bmw","audi"]
cars[0]='suzuki'
# print(cars.upper())
print(cars[0].upper())
# Out:
# SUZUKI

# %%
#exercise 04 solution coding and de coding

st=input('enter your mesage here: ')
words=st.split(" ")
coding = input("1 for coding 0 for Decoding: ")
coding = True if (coding=='1') else False
if (coding):
  nwords = []
  for word in words:
    if (len(word)>=3):
      r1='alm'
      r2='kom'
      stnew = r1 + word[1:]+word[0] + r2
      nwords.append(stnew)
    else:
      nwords.append(word[::-1])
  print(" ".join(nwords))
else:
  nwords = []
  for word in words:
    if (len(word)>=3):
      stnew= word[3:-3]
      stnew = stnew[-1]+stnew[:-1]

      nwords.append(stnew)
    else:
      nwords.append(word[::-1])
  print(" ".join(nwords))
# Out:
# enter your mesage here: almliakom si almoodgkom
# 1 for coding 0 for Decoding:
# ali is good

# %%
#short if else

a = 222
b = 333
print("A") if a > b  else print ("==") if a==b else print("B")
print(9) if a>b else""
# Out:
# B
# ''

# %%
 marks=[12,34,56,98,78,76,54,32]

# index = 0
# for mark in marks:
#   print(mark)
#   if (index == 3):
#     print("excellent work ")
#   # else:
#   #   print("not match")
#   index +=1

for index, mark in enumerate(marks, start=1):

  print(f'{index+0},{mark}')
  if (index == 3):
    print("excellent work ")
# Out:
# 1,12
# 2,34
# 3,56
# excellent work
# 4,98
# 5,78
# 6,76
# 7,54
# 8,32

# %%
s='hello'
print(s)
for index,c in enumerate(s):
  print("\n",index , c)
# Out:
# hello
#
#  0 h
#
#  1 e
#
#  2 l
#
#  3 l
#
#  4 o

# %%
# import math
from math import sqrt,pi
result=sqrt(9)*pi
print(result)
# math.floor(9.343)
# Out:
# 9.42477796076938

# %%
import math
print(dir(math))

import math as m
result=m.sqrt(9)*m.pi
print(result)
print(math.nan,type(math.nan))
# Out:
# ['__doc__', '__loader__', '__name__', '__package__', '__spec__', 'acos', 'acosh', 'asin', 'asinh', 'atan', 'atan2', 'atanh', 'cbrt', 'ceil', 'comb', 'copysign', 'cos', 'cosh', 'degrees', 'dist', 'e', 'erf', 'erfc', 'exp', 'exp2', 'expm1', 'fabs', 'factorial', 'floor', 'fmod', 'frexp', 'fsum', 'gamma', 'gcd', 'hypot', 'inf', 'isclose', 'isfinite', 'isinf', 'isnan', 'isqrt', 'lcm', 'ldexp', 'lgamma', 'log', 'log10', 'log1p', 'log2', 'modf', 'nan', 'nextafter', 'perm', 'pi', 'pow', 'prod', 'radians', 'remainder', 'sin', 'sinh', 'sqrt', 'tan', 'tanh', 'tau', 'trunc', 'ulp']
# 9.42477796076938
# nan <class 'float'>
